# %% [markdown]
#     Create project 31/05/2565
#     Create by moremoo
#     Project : Pandas read file

# %% [markdown]
# # Read CSV (Comma-Separated Values)

# %%
url = 'https://github.com/prasertcbs/basic-dataset/raw/master/BaskinRobbins.csv'
df = pd.read_csv(url)
df
# Out:
#                      Flavour  Calories  Total Fat (g)  Trans Fat (g)  \
# 0             Bananas Foster       160            8.0            0.2
# 1               Baseball Nut       160            9.0            0.2
# 2         Beavertails Pastry       170            9.0            0.3
# 3   Blackberry Frozen Yogurt       120            4.0            0.1
# 4     Blue Raspberry Sherbet       130            2.0            0.1
# ..                       ...       ...            ...            ...
# 65     Very Berry Strawberry       200           10.0            0.4
# 66         Watermelon Splash       120            0.5            0.0
# 67          Wild ‘n Reckless        80            1.5            0.0
# 68    Winter White Chocolate       160            8.0            0.2
# 69     World Class Chocolate       260           60.0            0.4
#
#     Carbohydrates (g)  Sugars (g)  Protein (g)
# 0                  20          16          2.0
# ...

# %% [markdown]
# # Read TSV (Tab-Separated Values)

# %%
url = 'https://github.com/prasertcbs/basic-dataset/raw/master/BaskinRobbins.tsv'
df = pd.read_table(url)
df
# Out:
#                      Flavour  Calories  Total Fat (g)  Trans Fat (g)  \
# 0             Bananas Foster       160            8.0            0.2
# 1               Baseball Nut       160            9.0            0.2
# 2         Beavertails Pastry       170            9.0            0.3
# 3   Blackberry Frozen Yogurt       120            4.0            0.1
# 4     Blue Raspberry Sherbet       130            2.0            0.1
# ..                       ...       ...            ...            ...
# 65     Very Berry Strawberry       200           10.0            0.4
# 66         Watermelon Splash       120            0.5            0.0
# 67          Wild ‘n Reckless        80            1.5            0.0
# 68    Winter White Chocolate       160            8.0            0.2
# 69     World Class Chocolate       260           60.0            0.4
#
#     Carbohydrates (g)  Sugars (g)  Protein (g)  Sugar Alcohol (g)
# 0                  20          16          2.0                NaN
# ...

# %% [markdown]
# # Read Excel

# %%
url = 'https://github.com/prasertcbs/basic-dataset/raw/master/BaskinRobbins.xlsx'
df = pd.read_excel(url)
df
# Out:
#                      Flavour  Calories  Total Fat (g)  Trans Fat (g)  \
# 0             Bananas Foster       160            8.0            0.2
# 1               Baseball Nut       160            9.0            0.2
# 2         Beavertails Pastry       170            9.0            0.3
# 3   Blackberry Frozen Yogurt       120            4.0            0.1
# 4     Blue Raspberry Sherbet       130            2.0            0.1
# ..                       ...       ...            ...            ...
# 65     Very Berry Strawberry       200           10.0            0.4
# 66         Watermelon Splash       120            0.5            0.0
# 67          Wild ‘n Reckless        80            1.5            0.0
# 68    Winter White Chocolate       160            8.0            0.2
# 69     World Class Chocolate       260           60.0            0.4
#
#     Carbohydrates (g)  Sugars (g)  Protein (g)  Sugar Alcohol (g)
# 0                  20          16          2.0                NaN
# ...

# %% [markdown]
# # Read Zip

# %% [markdown]
# ต้องรู้ด้านในเป็นไฟล์อะไร

# %%
url = 'https://github.com/prasertcbs/basic-dataset/raw/master/california-housing-prices.zip'
df = pd.read_csv(url)
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %% [markdown]
# # Read FWF (Fixed-Width Format)

# %% [markdown]
# pd.read_fwf(url, widths=[])

# %%
url = 'https://github.com/prasertcbs/basic-dataset/raw/master/planet.txt'
df = pd.read_fwf(url)
df
# Out:
#    Mercury
# 0    Venus
# 1      โลก
# 2     Mars
# 3  Jupiter
# 4    เสาร์
# 5  ยูเรนัส
# 6  Neptune

# %%
url = 'https://github.com/prasertcbs/basic-dataset/raw/master/planet.txt'
df = pd.read_fwf(url, widths=[2, 3, 1], names=['a', 'b', 'c'])
df
# Out:
#     a    b    c
# 0  Me  rcu    r
# 1  Ve  nus  NaN
# 2  โล    ก  NaN
# 3  Ma   rs  NaN
# 4  Ju  pit    e
# 5  เส  าร์  NaN
# 6  ยู  เรน    ั
# 7  Ne  ptu    n
